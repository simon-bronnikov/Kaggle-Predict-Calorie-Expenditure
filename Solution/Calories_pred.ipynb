# %%
from tqdm import tqdm
import optuna
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from xgboost import XGBRegressor

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import root_mean_squared_log_error

# %%
data = pd.read_csv('./data/train.csv')
data
# Out:
#             id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0            0    male   36   189.0    82.0      26.0       101.0       41.0
# 1            1  female   64   163.0    60.0       8.0        85.0       39.7
# 2            2  female   51   161.0    64.0       7.0        84.0       39.8
# 3            3    male   20   192.0    90.0      25.0       105.0       40.7
# 4            4  female   38   166.0    61.0      25.0       102.0       40.6
# ...        ...     ...  ...     ...     ...       ...         ...        ...
# 749995  749995    male   28   193.0    97.0      30.0       114.0       40.9
# 749996  749996  female   64   165.0    63.0      18.0        92.0       40.5
# 749997  749997    male   60   162.0    67.0      29.0       113.0       40.9
# 749998  749998    male   45   182.0    91.0      17.0       102.0       40.3
# 749999  749999  female   39   171.0    65.0      19.0        97.0       40.6
#
#         Calories
# 0          150.0
# 1           34.0
# 2           29.0
# 3          140.0
# 4          146.0
# ...          ...
# 749995     230.0
# 749996      96.0
# 749997     221.0
# 749998     109.0
# 749999     103.0
#
# [750000 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# id            0
# Sex           0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %%
data['Sex'] = data['Sex'].apply(lambda x: 1 if x == 'male' else 0)
data
# Out:
#             id  Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0            0    1   36   189.0    82.0      26.0       101.0       41.0
# 1            1    0   64   163.0    60.0       8.0        85.0       39.7
# 2            2    0   51   161.0    64.0       7.0        84.0       39.8
# 3            3    1   20   192.0    90.0      25.0       105.0       40.7
# 4            4    0   38   166.0    61.0      25.0       102.0       40.6
# ...        ...  ...  ...     ...     ...       ...         ...        ...
# 749995  749995    1   28   193.0    97.0      30.0       114.0       40.9
# 749996  749996    0   64   165.0    63.0      18.0        92.0       40.5
# 749997  749997    1   60   162.0    67.0      29.0       113.0       40.9
# 749998  749998    1   45   182.0    91.0      17.0       102.0       40.3
# 749999  749999    0   39   171.0    65.0      19.0        97.0       40.6
#
#         Calories
# 0          150.0
# 1           34.0
# 2           29.0
# 3          140.0
# 4          146.0
# ...          ...
# 749995     230.0
# 749996      96.0
# 749997     221.0
# 749998     109.0
# 749999     103.0
#
# [750000 rows x 9 columns]

# %%
data.drop(columns=['id'], inplace=True)

# %%
data.describe()
# Out:
#                  Sex            Age         Height         Weight  \
# count  750000.000000  750000.000000  750000.000000  750000.000000
# mean        0.499039      41.420404     174.697685      75.145668
# std         0.499999      15.175049      12.824496      13.982704
# min         0.000000      20.000000     126.000000      36.000000
# 25%         0.000000      28.000000     164.000000      63.000000
# 50%         0.000000      40.000000     174.000000      74.000000
# 75%         1.000000      52.000000     185.000000      87.000000
# max         1.000000      79.000000     222.000000     132.000000
#
#             Duration     Heart_Rate      Body_Temp       Calories
# count  750000.000000  750000.000000  750000.000000  750000.000000
# mean       15.421015      95.483995      40.036253      88.282781
# std         8.354095       9.449845       0.779875      62.395349
# min         1.000000      67.000000      37.100000       1.000000
# 25%         8.000000      88.000000      39.600000      34.000000
# 50%        15.000000      95.000000      40.300000      77.000000
# 75%        23.000000     103.000000      40.700000     136.000000
# max        30.000000     128.000000      41.500000     314.000000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
figure = plt.figure(figsize=(8, 6))

plt.scatter(data['Calories'], data['Heart_Rate'] * data['Duration'] * data['Body_Temp'])
plt.title('Heart Rate x Duration')
# Out:
# Text(0.5, 1.0, 'Heart Rate x Duration')

# %%
data['SMM'] = 0.244 * data['Weight'] + 7.8 * data['Height'] + 6.6 * data['Sex'] - 0.098 * data['Age'] + 0.4
data['BMI'] = data['Weight'] / (data['Height']/100)**2

#SMM - Skeletal Muscle Mass
#BMI - Body Mass Index

data.head(5)
# Out:
#    Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# 0    1   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1    0   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2    0   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3    1   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4    0   38   166.0    61.0      25.0       102.0       40.6     146.0
#
#         SMM        BMI
# 0  1497.680  22.955684
# 1  1280.168  22.582709
# 2  1266.818  24.690405
# 3  1524.600  24.414062
# 4  1306.360  22.136740

# %%
figure = plt.figure(figsize=(8, 10))

fig, (ax3, ax4) = plt.subplots(1, 2, figsize=(10, 6))

ax3.scatter(data['Calories'], data['Duration'] * data['SMM'] * data['Heart_Rate'])
ax3.set_title('Duration x Heart rate x SMM')

ax4.scatter(data['Calories'], data['Duration'] * data['BMI'] * data['Heart_Rate'] * data['Body_Temp'])
ax4.set_title('Duration x Heart rate x BMI x Body Temp')
# Out:
# Text(0.5, 1.0, 'Duration x Heart rate x BMI x Body Temp')

# %%
data['SMM_DUR_HEART'] = data['Duration'] * data['SMM'] * data['Heart_Rate']
data['Cardio'] = data['Heart_Rate'] * data['Duration'] * data['Body_Temp']

data.head(5)
# Out:
#    Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories  \
# 0    1   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1    0   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2    0   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3    1   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4    0   38   166.0    61.0      25.0       102.0       40.6     146.0
#
#         SMM        BMI  SMM_DUR_HEART    Cardio
# 0  1497.680  22.955684    3932907.680  107666.0
# 1  1280.168  22.582709     870514.240   26996.0
# 2  1266.818  24.690405     744888.984   23402.4
# 3  1524.600  24.414062    4002075.000  106837.5
# 4  1306.360  22.136740    3331218.000  103530.0

# %%
X = data.drop(columns=['Calories'])
y = data['Calories']

# %%
numeric_cols = X.select_dtypes(include=np.number).columns.tolist()

scaler = StandardScaler()
scaler.fit(X[numeric_cols])
X[numeric_cols] = scaler.transform(X[numeric_cols])

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10)
    }
    model = XGBRegressor(**params, random_state=42, n_jobs=-1, tree_method='hist')

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = []

    for train_idx, val_idx in kf.split(X, y):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)
        y_pred = np.clip(y_pred, 0, None) 

        rmsle = root_mean_squared_log_error(y_val, y_pred)
        scores.append(rmsle)

    return np.mean(scores)

# %%
n_trials = 50
pbar = tqdm(total=n_trials, desc="Optuna search")

def callback(study, trial):
    pbar.update(1)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50, callbacks=[callback])
print(f'Best hyperparameters: {study.best_params}')

pbar.close()
# Out:
# Optuna search:   0%|          | 0/50 [00:00<?, ?it/s][I 2025-06-13 16:05:17,542] A new study created in memory with name: no-name-bd515c90-0c7d-4a6c-9c5f-c232786b0f72
# [I 2025-06-13 16:05:28,633] Trial 0 finished with value: 0.06369264127152834 and parameters: {'n_estimators': 295, 'max_depth': 6, 'learning_rate': 0.14318704611062438, 'subsample': 0.8070403907984343, 'colsample_bytree': 0.9661954359194744, 'gamma': 2.6785483764122593, 'min_child_weight': 8}. Best is trial 0 with value: 0.06369264127152834.
# Optuna search:   2%|▏         | 1/50 [00:11<09:03, 11.09s/it][I 2025-06-13 16:05:58,989] Trial 1 finished with value: 0.0638469312196637 and parameters: {'n_estimators': 559, 'max_depth': 9, 'learning_rate': 0.25860564017258625, 'subsample': 0.8732245762212638, 'colsample_bytree': 0.6046115457507114, 'gamma': 4.339639209010914, 'min_child_weight': 3}. Best is trial 0 with value: 0.06369264127152834.
# Optuna search:   4%|▍         | 2/50 [00:41<17:56, 22.42s/it][I 2025-06-13 16:06:44,486] Trial 2 finished with value: 0.06145004769726005 and parameters: {'n_estimators': 697, 'max_depth': 10, 'learning_rate': 0.059502094508217945, 'subsample': 0.7528592618192465, 'colsample_bytree': 0.6842420720043304, 'gamma': 2.7152679337217096, 'min_child_weight': 6}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:   6%|▌         | 3/50 [01:26<25:49, 32.96s/it][I 2025-06-13 16:07:05,973] Trial 3 finished with value: 0.06195189872751884 and parameters: {'n_estimators': 314, 'max_depth': 10, 'learning_rate': 0.09345853768930644, 'subsample': 0.7097153849758706, 'colsample_bytree': 0.5909950255943417, 'gamma': 2.6538494836022943, 'min_child_weight': 8}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:   8%|▊         | 4/50 [01:48<21:47, 28.43s/it][I 2025-06-13 16:07:28,609] Trial 4 finished with value: 0.06326613650155741 and parameters: {'n_estimators': 530, 'max_depth': 7, 'learning_rate': 0.19911495921087982, 'subsample': 0.7880633559114453, 'colsample_bytree': 0.795953470261462, 'gamma': 4.559256541017126, 'min_child_weight': 8}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  10%|█         | 5/50 [02:11<19:45, 26.34s/it][I 2025-06-13 16:07:40,458] Trial 5 finished with value: 0.07647789856050151 and parameters: {'n_estimators': 482, 'max_depth': 3, 'learning_rate': 0.18214691065937128, 'subsample': 0.8993923015748144, 'colsample_bytree': 0.922251891046749, 'gamma': 2.6065466988789288, 'min_child_weight': 9}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  12%|█▏        | 6/50 [02:22<15:42, 21.41s/it][I 2025-06-13 16:07:58,175] Trial 6 finished with value: 0.062481615442497175 and parameters: {'n_estimators': 349, 'max_depth': 9, 'learning_rate': 0.24257038340827777, 'subsample': 0.9858742968389519, 'colsample_bytree': 0.9718298016305593, 'gamma': 2.6884189300007044, 'min_child_weight': 3}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  14%|█▍        | 7/50 [02:40<14:28, 20.21s/it][I 2025-06-13 16:08:10,014] Trial 7 finished with value: 0.066116904884886 and parameters: {'n_estimators': 310, 'max_depth': 5, 'learning_rate': 0.11409008846515258, 'subsample': 0.7444465568540592, 'colsample_bytree': 0.5677709272936966, 'gamma': 1.337436861536987, 'min_child_weight': 1}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  16%|█▌        | 8/50 [02:52<12:16, 17.54s/it][I 2025-06-13 16:08:18,266] Trial 8 finished with value: 0.07251373010064377 and parameters: {'n_estimators': 258, 'max_depth': 4, 'learning_rate': 0.13734633043723626, 'subsample': 0.7586296513929891, 'colsample_bytree': 0.966873300760805, 'gamma': 4.433140315766227, 'min_child_weight': 9}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  18%|█▊        | 9/50 [03:00<10:00, 14.64s/it][I 2025-06-13 16:08:57,217] Trial 9 finished with value: 0.06294874833334928 and parameters: {'n_estimators': 932, 'max_depth': 7, 'learning_rate': 0.1244917860550076, 'subsample': 0.6729551542096088, 'colsample_bytree': 0.7675550531667685, 'gamma': 0.9440784498670485, 'min_child_weight': 9}. Best is trial 2 with value: 0.06145004769726005.
# Optuna search:  20%|██        | 10/50 [03:39<14:45, 22.14s/it][I 2025-06-13 16:10:07,049] Trial 10 finished with value: 0.06111327231992787 and parameters: {'n_estimators': 817, 'max_depth': 10, 'learning_rate': 0.014329238830433154, 'subsample': 0.5445450763542414, 'colsample_bytree': 0.688951123848331, 'gamma': 3.579507730572069, 'min_child_weight': 5}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  22%|██▏       | 11/50 [04:49<23:52, 36.74s/it][I 2025-06-13 16:11:11,670] Trial 11 finished with value: 0.06122659387228642 and parameters: {'n_estimators': 842, 'max_depth': 10, 'learning_rate': 0.024920814518138656, 'subsample': 0.5088947660150596, 'colsample_bytree': 0.6848153386698341, 'gamma': 3.555148037547686, 'min_child_weight': 5}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  24%|██▍       | 12/50 [05:54<28:38, 45.22s/it][I 2025-06-13 16:12:23,866] Trial 12 finished with value: 0.06170269543682352 and parameters: {'n_estimators': 964, 'max_depth': 8, 'learning_rate': 0.012174718211844255, 'subsample': 0.5071340623188727, 'colsample_bytree': 0.6738264554648213, 'gamma': 3.6983768246095385, 'min_child_weight': 5}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  26%|██▌       | 13/50 [07:06<32:55, 53.39s/it][I 2025-06-13 16:13:31,086] Trial 13 finished with value: 0.06126723437741678 and parameters: {'n_estimators': 776, 'max_depth': 9, 'learning_rate': 0.011106316626183164, 'subsample': 0.5047625449153311, 'colsample_bytree': 0.8379988424508457, 'gamma': 3.6115252841432794, 'min_child_weight': 5}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  28%|██▊       | 14/50 [08:13<34:32, 57.57s/it][I 2025-06-13 16:14:28,229] Trial 14 finished with value: 0.06164982440355353 and parameters: {'n_estimators': 820, 'max_depth': 10, 'learning_rate': 0.05612694511368266, 'subsample': 0.6069148607221138, 'colsample_bytree': 0.6780712332618922, 'gamma': 3.566359342133251, 'min_child_weight': 6}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  30%|███       | 15/50 [09:10<33:30, 57.44s/it][I 2025-06-13 16:14:36,833] Trial 15 finished with value: 0.06647469990387003 and parameters: {'n_estimators': 111, 'max_depth': 8, 'learning_rate': 0.05821910365248371, 'subsample': 0.5860946976893622, 'colsample_bytree': 0.5060994687583023, 'gamma': 1.7268101896497368, 'min_child_weight': 3}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  32%|███▏      | 16/50 [09:19<24:13, 42.74s/it][I 2025-06-13 16:15:17,855] Trial 16 finished with value: 0.06160619835509172 and parameters: {'n_estimators': 690, 'max_depth': 8, 'learning_rate': 0.033846106580017084, 'subsample': 0.5854935746735612, 'colsample_bytree': 0.719053410761146, 'gamma': 3.3986659425543433, 'min_child_weight': 4}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  34%|███▍      | 17/50 [10:00<23:13, 42.22s/it][I 2025-06-13 16:16:27,001] Trial 17 finished with value: 0.061780406966486845 and parameters: {'n_estimators': 879, 'max_depth': 10, 'learning_rate': 0.08808374045403274, 'subsample': 0.6335663034107211, 'colsample_bytree': 0.8522067823650974, 'gamma': 0.1606874505909044, 'min_child_weight': 1}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  36%|███▌      | 18/50 [11:09<26:50, 50.31s/it][I 2025-06-13 16:16:54,123] Trial 18 finished with value: 0.06705960377524253 and parameters: {'n_estimators': 646, 'max_depth': 6, 'learning_rate': 0.2967489536254194, 'subsample': 0.5365264079633051, 'colsample_bytree': 0.6333585093560005, 'gamma': 4.983701931124898, 'min_child_weight': 7}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  38%|███▊      | 19/50 [11:36<22:23, 43.35s/it][I 2025-06-13 16:17:45,537] Trial 19 finished with value: 0.062086229623901854 and parameters: {'n_estimators': 806, 'max_depth': 9, 'learning_rate': 0.08643707069268243, 'subsample': 0.5483115371374196, 'colsample_bytree': 0.7301622815686636, 'gamma': 1.881709411204059, 'min_child_weight': 4}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  40%|████      | 20/50 [12:27<22:53, 45.77s/it][I 2025-06-13 16:18:38,260] Trial 20 finished with value: 0.0639712140949118 and parameters: {'n_estimators': 976, 'max_depth': 8, 'learning_rate': 0.17287027462566174, 'subsample': 0.6700856390945517, 'colsample_bytree': 0.5349667326526197, 'gamma': 3.8129270542008555, 'min_child_weight': 7}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  42%|████▏     | 21/50 [13:20<23:07, 47.86s/it][I 2025-06-13 16:19:51,974] Trial 21 finished with value: 0.06132782862799783 and parameters: {'n_estimators': 778, 'max_depth': 9, 'learning_rate': 0.010115944047791937, 'subsample': 0.5093127312860396, 'colsample_bytree': 0.8349263920122334, 'gamma': 3.1664334239455343, 'min_child_weight': 5}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  44%|████▍     | 22/50 [14:34<25:57, 55.62s/it][I 2025-06-13 16:20:52,351] Trial 22 finished with value: 0.06120983837998657 and parameters: {'n_estimators': 752, 'max_depth': 10, 'learning_rate': 0.03572410130794628, 'subsample': 0.5613550721995432, 'colsample_bytree': 0.8694186197359035, 'gamma': 3.913504910631715, 'min_child_weight': 4}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  46%|████▌     | 23/50 [15:34<25:40, 57.05s/it][I 2025-06-13 16:22:03,638] Trial 23 finished with value: 0.06122868245034889 and parameters: {'n_estimators': 856, 'max_depth': 10, 'learning_rate': 0.038434378773015254, 'subsample': 0.5613765490235144, 'colsample_bytree': 0.8936405857385912, 'gamma': 4.126985004649535, 'min_child_weight': 4}. Best is trial 10 with value: 0.06111327231992787.
# Optuna search:  48%|████▊     | 24/50 [16:46<26:34, 61.32s/it][I 2025-06-13 16:23:05,425] Trial 24 finished with value: 0.06109403436253311 and parameters: {'n_estimators': 634, 'max_depth': 10, 'learning_rate': 0.045003019956453755, 'subsample': 0.6387017433604564, 'colsample_bytree': 0.7791144999434744, 'gamma': 3.1403906893960976, 'min_child_weight': 2}. Best is trial 24 with value: 0.06109403436253311.
# Optuna search:  50%|█████     | 25/50 [17:47<25:36, 61.46s/it][I 2025-06-13 16:23:50,029] Trial 25 finished with value: 0.06139607427965741 and parameters: {'n_estimators': 615, 'max_depth': 9, 'learning_rate': 0.06917368175031602, 'subsample': 0.6292981344780899, 'colsample_bytree': 0.7737681555891338, 'gamma': 3.173585280005987, 'min_child_weight': 2}. Best is trial 24 with value: 0.06109403436253311.
# Optuna search:  52%|█████▏    | 26/50 [18:32<22:33, 56.40s/it][I 2025-06-13 16:24:31,602] Trial 26 finished with value: 0.06089781673877185 and parameters: {'n_estimators': 439, 'max_depth': 10, 'learning_rate': 0.03530918009972066, 'subsample': 0.6617954578194825, 'colsample_bytree': 0.8905458424231938, 'gamma': 2.1461400479047867, 'min_child_weight': 2}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  54%|█████▍    | 27/50 [19:14<19:54, 51.95s/it][I 2025-06-13 16:25:04,814] Trial 27 finished with value: 0.06192321444198734 and parameters: {'n_estimators': 435, 'max_depth': 8, 'learning_rate': 0.10836743321225961, 'subsample': 0.6713749921505798, 'colsample_bytree': 0.8023835929167329, 'gamma': 2.1225833911454677, 'min_child_weight': 2}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  56%|█████▌    | 28/50 [19:47<16:59, 46.33s/it][I 2025-06-13 16:25:30,653] Trial 28 finished with value: 0.06237677640971282 and parameters: {'n_estimators': 419, 'max_depth': 7, 'learning_rate': 0.04823237530136644, 'subsample': 0.7098975840253617, 'colsample_bytree': 0.9208559965890191, 'gamma': 2.212591654329131, 'min_child_weight': 2}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  58%|█████▊    | 29/50 [20:13<14:03, 40.18s/it][I 2025-06-13 16:25:54,447] Trial 29 finished with value: 0.06513311981965787 and parameters: {'n_estimators': 572, 'max_depth': 5, 'learning_rate': 0.07560316689233185, 'subsample': 0.6294986455204288, 'colsample_bytree': 0.727502402869884, 'gamma': 3.0745887847313136, 'min_child_weight': 10}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  60%|██████    | 30/50 [20:36<11:45, 35.27s/it][I 2025-06-13 16:26:07,883] Trial 30 finished with value: 0.0619989759881888 and parameters: {'n_estimators': 165, 'max_depth': 9, 'learning_rate': 0.15215669274170202, 'subsample': 0.6929805655133383, 'colsample_bytree': 0.6374080516684035, 'gamma': 1.4023053553088696, 'min_child_weight': 1}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  62%|██████▏   | 31/50 [20:50<09:05, 28.72s/it][I 2025-06-13 16:27:08,925] Trial 31 finished with value: 0.061106064980940754 and parameters: {'n_estimators': 708, 'max_depth': 10, 'learning_rate': 0.03295353813275885, 'subsample': 0.577737418884641, 'colsample_bytree': 0.876460619329793, 'gamma': 3.9159504441089283, 'min_child_weight': 3}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  64%|██████▍   | 32/50 [21:51<11:31, 38.41s/it][I 2025-06-13 16:28:15,387] Trial 32 finished with value: 0.06114742352688035 and parameters: {'n_estimators': 708, 'max_depth': 10, 'learning_rate': 0.026386383497273045, 'subsample': 0.5962868020583203, 'colsample_bytree': 0.9202934460870862, 'gamma': 2.8782269763654376, 'min_child_weight': 3}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  66%|██████▌   | 33/50 [22:57<13:16, 46.83s/it][I 2025-06-13 16:29:06,849] Trial 33 finished with value: 0.06118910516190769 and parameters: {'n_estimators': 617, 'max_depth': 9, 'learning_rate': 0.04545963056233632, 'subsample': 0.6440873709538288, 'colsample_bytree': 0.9983586165048322, 'gamma': 4.0895703412649915, 'min_child_weight': 2}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  68%|██████▊   | 34/50 [23:49<12:51, 48.22s/it][I 2025-06-13 16:29:54,391] Trial 34 finished with value: 0.06115085944203119 and parameters: {'n_estimators': 553, 'max_depth': 10, 'learning_rate': 0.055439674202279354, 'subsample': 0.6070883924564036, 'colsample_bytree': 0.888962424345529, 'gamma': 2.344750714430711, 'min_child_weight': 2}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  70%|███████   | 35/50 [24:36<12:00, 48.02s/it][I 2025-06-13 16:30:41,071] Trial 35 finished with value: 0.06163799470806923 and parameters: {'n_estimators': 502, 'max_depth': 10, 'learning_rate': 0.07144994861785844, 'subsample': 0.5427628457343374, 'colsample_bytree': 0.7964909406335359, 'gamma': 4.752763209376791, 'min_child_weight': 3}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  72%|███████▏  | 36/50 [25:23<11:06, 47.62s/it][I 2025-06-13 16:31:36,683] Trial 36 finished with value: 0.06134529035468148 and parameters: {'n_estimators': 716, 'max_depth': 9, 'learning_rate': 0.10370287997923239, 'subsample': 0.8259073064805152, 'colsample_bytree': 0.8152676766419666, 'gamma': 4.198898018884197, 'min_child_weight': 1}. Best is trial 26 with value: 0.06089781673877185.
# Optuna search:  74%|███████▍  | 37/50 [26:19<10:50, 50.01s/it][I 2025-06-13 16:32:39,182] Trial 37 finished with value: 0.06089093695413379 and parameters: {'n_estimators': 656, 'max_depth': 10, 'learning_rate': 0.026316344391021124, 'subsample': 0.729017291223931, 'colsample_bytree': 0.8810913305838564, 'gamma': 2.9204911860232063, 'min_child_weight': 3}. Best is trial 37 with value: 0.06089093695413379.
# Optuna search:  76%|███████▌  | 38/50 [27:21<10:45, 53.76s/it][I 2025-06-13 16:32:53,077] Trial 38 finished with value: 0.10867360434998989 and parameters: {'n_estimators': 449, 'max_depth': 3, 'learning_rate': 0.07652270204102618, 'subsample': 0.7254668747064079, 'colsample_bytree': 0.9486397317026523, 'gamma': 2.8477075084583583, 'min_child_weight': 3}. Best is trial 37 with value: 0.06089093695413379.
# Optuna search:  78%|███████▊  | 39/50 [27:35<07:39, 41.80s/it][I 2025-06-13 16:33:41,091] Trial 39 finished with value: 0.06313653290968055 and parameters: {'n_estimators': 665, 'max_depth': 9, 'learning_rate': 0.22750845719224555, 'subsample': 0.8140703542982278, 'colsample_bytree': 0.8890924515134317, 'gamma': 2.5502381577238844, 'min_child_weight': 2}. Best is trial 37 with value: 0.06089093695413379.
# Optuna search:  80%|████████  | 40/50 [28:23<07:16, 43.66s/it][I 2025-06-13 16:34:34,520] Trial 40 finished with value: 0.060844672582148464 and parameters: {'n_estimators': 581, 'max_depth': 10, 'learning_rate': 0.027729440803207755, 'subsample': 0.773055853128417, 'colsample_bytree': 0.866644971570646, 'gamma': 3.284841367092004, 'min_child_weight': 3}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  82%|████████▏ | 41/50 [29:16<06:59, 46.59s/it][I 2025-06-13 16:35:28,135] Trial 41 finished with value: 0.061098199036746646 and parameters: {'n_estimators': 618, 'max_depth': 10, 'learning_rate': 0.03375307432321094, 'subsample': 0.7688805993208248, 'colsample_bytree': 0.937245009905728, 'gamma': 3.209473596657814, 'min_child_weight': 3}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  84%|████████▍ | 42/50 [30:10<06:29, 48.70s/it][I 2025-06-13 16:36:12,688] Trial 42 finished with value: 0.061024365118248936 and parameters: {'n_estimators': 381, 'max_depth': 10, 'learning_rate': 0.026039675398177555, 'subsample': 0.7814407832209529, 'colsample_bytree': 0.9398038073517175, 'gamma': 3.252518285954199, 'min_child_weight': 4}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  86%|████████▌ | 43/50 [30:55<05:32, 47.46s/it][I 2025-06-13 16:36:54,713] Trial 43 finished with value: 0.061011241512396154 and parameters: {'n_estimators': 409, 'max_depth': 9, 'learning_rate': 0.022897960049000007, 'subsample': 0.8864023003934873, 'colsample_bytree': 0.9050919681885696, 'gamma': 2.933251036804258, 'min_child_weight': 4}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  88%|████████▊ | 44/50 [31:37<04:34, 45.83s/it][I 2025-06-13 16:37:32,668] Trial 44 finished with value: 0.061134884580475626 and parameters: {'n_estimators': 370, 'max_depth': 9, 'learning_rate': 0.0230644480527945, 'subsample': 0.855990524380515, 'colsample_bytree': 0.9993326368084245, 'gamma': 2.4122711163048973, 'min_child_weight': 4}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  90%|█████████ | 45/50 [32:15<03:37, 43.47s/it][I 2025-06-13 16:38:00,263] Trial 45 finished with value: 0.06106883238806127 and parameters: {'n_estimators': 269, 'max_depth': 10, 'learning_rate': 0.06433273441494605, 'subsample': 0.9173851717089275, 'colsample_bytree': 0.9081659883125165, 'gamma': 2.7712969038853252, 'min_child_weight': 4}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  92%|█████████▏| 46/50 [32:42<02:34, 38.70s/it][I 2025-06-13 16:38:39,996] Trial 46 finished with value: 0.06125893591213315 and parameters: {'n_estimators': 391, 'max_depth': 9, 'learning_rate': 0.021497210585030024, 'subsample': 0.7901396807279306, 'colsample_bytree': 0.945399373327797, 'gamma': 1.876377071610276, 'min_child_weight': 6}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  94%|█████████▍| 47/50 [33:22<01:57, 39.01s/it][I 2025-06-13 16:39:15,020] Trial 47 finished with value: 0.0616750377839143 and parameters: {'n_estimators': 488, 'max_depth': 10, 'learning_rate': 0.12880852545533597, 'subsample': 0.9583512932373649, 'colsample_bytree': 0.9687551423192944, 'gamma': 3.327119222247057, 'min_child_weight': 4}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  96%|█████████▌| 48/50 [33:57<01:15, 37.82s/it][I 2025-06-13 16:39:24,290] Trial 48 finished with value: 0.08770485356345539 and parameters: {'n_estimators': 218, 'max_depth': 4, 'learning_rate': 0.05087437723384751, 'subsample': 0.8430353774441681, 'colsample_bytree': 0.8665465858089503, 'gamma': 2.9407974663482377, 'min_child_weight': 3}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search:  98%|█████████▊| 49/50 [34:06<00:29, 29.25s/it][I 2025-06-13 16:39:52,090] Trial 49 finished with value: 0.0625198120492588 and parameters: {'n_estimators': 328, 'max_depth': 8, 'learning_rate': 0.019691621459468026, 'subsample': 0.8987888652983085, 'colsample_bytree': 0.8306108350471124, 'gamma': 2.6263316687330427, 'min_child_weight': 5}. Best is trial 40 with value: 0.060844672582148464.
# Optuna search: 100%|██████████| 50/50 [34:34<00:00, 41.49s/it]
# Best hyperparameters: {'n_estimators': 581, 'max_depth': 10, 'learning_rate': 0.027729440803207755, 'subsample': 0.773055853128417, 'colsample_bytree': 0.866644971570646, 'gamma': 3.284841367092004, 'min_child_weight': 3}

# %%
X_test = pd.read_csv('./data/test.csv')
X_test['Sex'] = X_test['Sex'].apply(lambda x: 1 if x == 'male' else 0)
X_test.drop(columns=['id'], inplace=True)


X_test['SMM'] = 0.244 * X_test['Weight'] + 7.8 * X_test['Height'] + 6.6 * X_test['Sex'] - 0.098 * X_test['Age'] + 0.4
X_test['BMI'] = X_test['Weight'] / (X_test['Height']/100)**2
X_test['SMM_DUR_HEART'] = X_test['Duration'] * X_test['SMM'] * X_test['Heart_Rate']
X_test['Cardio'] = X_test['Heart_Rate'] * X_test['Duration'] * X_test['Body_Temp']

numeric_cols=X_test.select_dtypes(include=np.number).columns.tolist()

scaler = StandardScaler()
scaler.fit(X_test[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# %%
params = {'n_estimators': 581, 'max_depth': 10, 'learning_rate': 0.027729440803207755, 'subsample': 0.773055853128417, 'colsample_bytree': 0.866644971570646, 'gamma': 3.284841367092004, 'min_child_weight': 3}

model=XGBRegressor(**params,random_state=42,n_jobs=-1,tree_method="hist")

model.fit(X, y)

y_pred = model.predict(X_test)
y_pred = np.clip(y_pred, 0, None)
# Out:
# Cross Validation RMSLE: 0.0

# %%
submission_df = pd.read_csv('./data/sample_submission.csv')
submission_df['Calories'] = y_pred
submission_df.to_csv('submission.csv', index=False)
